# %%
import os; os.chdir('..')

# %%
from Utils.html_tag_extractor import html_tag_extractor

# %%
# html_tag_extractor.print_html_raw('https://www.igeeksblog.com/best-cat-ear-headphones/')

# %%
html_tag_extractor.extract_html_template('https://www.igeeksblog.com/best-cat-ear-headphones/')
# Out:
# '<[document]><html><head><title>text</title></head><body><div></div><div><div><nav><div><a><img></a><a><img></a></div><span><i></i></span></nav></div><aside><div><div><div><ul><li><a>text</a><ul><li><a>text</a></li></ul></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></div></div><div><div><p>text</p><a><img></a></div></div><div><div><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></div></div><div><div><p>text</p><iframe></iframe></div></div><div><div><div><div><a><i></i></a></div><div><a><i></i></a></div><div><a><i></i></a></div><div><a><i></i></a></div><div><a><i></i></a></div><div><a><img></a></div></div></div></div><div><div><a><img></a><br>text</div></div></div></aside></div><div><div><header><div><div><div><span><i></i></span><div><a><img></a><a><img></a></div><nav><ul><li><a><span>text</span></a><ul><li><a>text</a></li></ul></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></nav></div><div><span><i></i><span></span><i></i></span><span><i></i></span><a>text</a></div></div><div><div><span><i></i></span></div><div><div><a><img></a><a><img></a></div></div><div><span><i></i><i></i></span><span><i></i></span></div></div></div><div><div><form><div><button><i></i></button><input><button><i></i></button></div></form><div><div></div></div></div></div></header><main><div><div><div><div><div><div><div><div><ul><li><a>text</a></li></ul></div><h1><span>text</span></h1><div><div><a><span>text</span><span>text</span></a></div><div>text</div><div><span><i></i></span>text</div></div></div><figure><img></figure></div></div><div><div><div><div><div><div><div><a><i></i></a></div><div><a><i></i></a></div><div><a><i></i></a></div><div><a><i></i></a></div><div><a><i></i></a></div><div><a><i></i></a></div></div></div></div></div><div><div><p>text</p><p>text</p><ol><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ol><p></p><h2><span><strong>text</strong></span></h2><div><figure><img></figure></div><p>text</p><p>text</p><p>text</p><p>text</p><div><div><p><strong>text</strong></p><ul><li>text</li><li>text</li><li>text</li><li>text</li><li>text</li></ul></div><div><p><strong>text</strong></p><ul><li>text</li></ul></div></div><p><a>text</a>text<a>text</a></p><h2><span><strong>text</strong>text<strong>text</strong></span></h2><div><figure><img></figure></div><p>text</p><p>text</p><p>text</p><div><div><p><strong>text</strong></p><ul><li>text</li><li>text</li><li>text</li><li>text</li></ul></div><div><p><strong>text</strong></p><ul><li>text</li><li>text</li></ul></div></div><p><a>text</a></p><h2><span><strong>text</strong></span></h2><div><figure><img></figure></div><p>text</p><p>text</p><p>text</p><div><div><p><strong>text</strong></p><ul><li>text</li><li>text</li><li>text</li><li>text</li></ul></div><div><p><strong>text</strong></p><ul><li>text</li></ul></div></div><p><a>text</a></p><h2><span><strong>text</strong>text<strong>text</strong></span></h2><div><figure><img></figure></div><p>text</p><p>text</p><p>text</p><div><div><p><strong>text</strong></p><ul><li>text</li><li>text</li><li>text</li></ul></div><div><p><strong>text</strong></p><ul><li>text</li></ul></div></div><p><a>text</a></p><h2><span><strong>text</strong>text<strong>text</strong></span></h2><div><figure><img></figure></div><p>text<a>text</a>text</p><p>text<a>text</a>text</p><p>text</p><div><div><p><strong>text</strong></p><ul><li>text</li><li>text</li><li>text</li><li>text</li></ul></div><div><p><strong>text</strong></p><ul><li>text</li><li>text</li></ul></div></div><p>< ...

# %%
url= "https://python.langchain.com/docs/integrations/chat/anthropic"

html_tag_extractor.extract_html_template(url)
# Out:
# '<[document]><html><head><title>text</title></head><body><div><div><a>text</a></div><nav><div><div><button><svg><path></path></svg></button><a><b>text</b></a><a>text</a><a>text</a><a>text</a><a>text<svg><path></path></svg></a></div><div><a>text</a><a>text</a><a></a><div><button><svg><path></path></svg><svg><path></path></svg></button></div><div><div><button><div><svg><path></path><path></path></svg><input></div><div><span>text</span><span>text</span></div></button><div></div></div></div></div></div><div></div></nav><div><button></button><div><aside><div><div><nav><ul><li><div><a>text</a></div><ul><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li><li><div><a>text</a><button></button></div></li></ul></li></ul></nav><button><svg><g><path></path><path></path></g></svg></button></div></div></aside><main><div><div><div><div><article><nav><ul><li><a><svg><path></path></svg></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><span>text</span></li></ul></nav><div><button>text</button></div><div><h1>text</h1><p>text</p><div><div><pre><code><span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><br></span><span><span></span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><span></span><span>text</span><span></span><br></span><span><span>text</span><span>text</span><span></span><br></span><span><span>text</span><span>text</span><span></span><br></span><span><span>text</span><span>text</span><span></span><br></span><span><span>text</span><span>text</span><span></span><br></span><span><span></span><span>text</span><span></span><br></span><span><span></span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><br></span></code></pre><div><button><span><svg><path></path></svg><svg><path></path></svg></span></button></div></div></div><div><h4>text</h4><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></div><div><div><pre><code><span><span>text</span><span>text</span><span>text</span><span>text</span><span>text</span><br></span></code></pre><div><button><span><svg><path></path></svg><svg><path></path></svg></span></button></div></div></div><div><div><pre><code><span><span>text</span><span>text</span><span></span><span>text</span><span></span><br></span><span><span>text</span><span>text</span><span></span><br></span><span><span>text</span><span>text</span><span>text</span><span></span><br></span><span><span></span><span>text</span><span></span><br></span><span><span></span><span>text</span><span></span><br></span><span><span>text</span><span>text</span><span>text</span><span>text</span><br></span></code></pre><div><button><span><svg><path></path></svg><svg><path></path></svg></span></button></div></div></div><div><div><div><pre><code><span><span>text</span><br></spa ...

# %%
from Utils.client import generate_top_urls

# %%
list_of_urls= generate_top_urls("Spotify free vs premium", 10)
list_of_urls
# Out:
# ['https://www.tomsguide.com/face-off/spotify-free-vs-premium',
#  'https://www.soundguys.com/free-spotify-vs-spotify-premium-36632/',
#  'https://www.headphonesty.com/2021/08/spotify-free-vs-premium/',
#  'https://history-computer.com/spotify-free-vs-premium-comparison-whats-the-difference/',
#  'https://www.cnet.com/tech/services-and-software/good-reasons-to-pay-for-spotify/',
#  'https://support.spotify.com/us/article/premium-plans/',
#  'https://www.geeky-gadgets.com/whats-difference-between-spotify-free-and-premium/',
#  'https://blog.tunemymusic.com/spotify-free-vs-premium-a-full-comparison/',
#  'https://www.howtogeek.com/350288/spotify-free-vs-premium-is-it-worth-upgrading/',
#  'https://www.makeuseof.com/spotify-free-vs-spotify-premium-main-differences/']

# %%
# idx= [0, 3, 4]

# %%
# html_templates= ''


# for i in idx:
#     template= html_tag_extractor.extract_html_template(list_of_urls[i])
#     if template:
#         print(template)
#         print(list_of_urls[i])
#         print()
#         html_templates+=template+'\n'
        
#         with open(f'dummy_files/template-{i}.html', 'w') as f:
#             f.write(list_of_urls[i]+template)
#         i+=1
# Out:
# <[document]><html><head><title>text</title></head><body><div><div><a>text</a><div><div><div><div><a><svg><title>text</title><desc>text</desc><path></path></svg></a><a><span>text</span></a></div></div><div><nav><ul><li><a><span>text</span><svg><title>text</title><desc>text</desc><path></path></svg></a><span>text</span></li><li><a>text</a><span>text</span></li><li><a>text</a><span>text</span></li><li><a>text</a><span>text</span></li><li><a>text</a><span>text</span></li><li><button><span>text</span><span>text</span><svg><title>text</title><path></path></svg></button></li></ul></nav></div></div><div><div><a><svg><title>text</title><desc>text</desc><path></path></svg></a><div><button><span>text</span><svg><title>text</title><path></path></svg></button></div></div></div></div><div><div></div><div></div><main><article><div><div><div><div><ul><li><a>text</a></li></ul><div><h1>text</h1></div><h2>text</h2></div><div><div><p><span>text</span><span><span></span><span><a>text</a></span><span>text<span>text</span></span></span></p></div><div><div></div></div></div></div><div><div><span><time>texttext</time></span><span>text</span><span><button><svg><title>text</title><path></path></svg><span><span></span></span></button></span></div><div><div><div><h2>text</h2><ul><li><button><svg><path></path></svg></button></li><li><button><svg><path></path></svg></button></li><li><div><button><svg><path></path></svg></button></div></li></ul></div><div><div></div></div></div></div><p>text<a>text</a></p></div></div><div><div></div><div><figure><span><span></span><img></span><div><figcaption><em>text</em></figcaption><cite>text</cite></div></figure></div><div><figure><span><span></span><img></span><div><figcaption><em>text</em></figcaption><cite>text</cite></div></figure></div></div></div><div><div><div><div><p>text</p></div><div><p>text</p></div><div><div><h3>text</h3><ul><li><a>text</a></li></ul></div></div><div><p>text</p></div><div><p>text</p></div><div><div><div><h3>text</h3></div><div><h4>text</h4></div><div><p>text</p></div><div><h4>text</h4></div><div><p>text</p></div><div><h4>text</h4></div><div><p>text</p></div><div><h4>text</h4></div><div><p>text</p></div><div><h4>text</h4></div><div><p>text</p></div><div><h4>text</h4></div><div><p>text</p></div><div><div></div></div></div></div><div><p>text<strong></strong><a>text</a>text</p></div><div><div><div></div></div></div><div><h3>text</h3></div><div><div><a><span><img></span></a><a><span><img></span></a><div><div><h3><a>text</a></h3></div><div><span>texttext</span></div><p>text</p><div><a>text</a><a>text</a><a>text</a></div></div></div></div><div><p><small><em><strong>text</strong>text<strong>text</strong>text<strong>text</strong>text<strong>text</strong>text</em></small></p></div><div><p>text</p></div><div><p>text</p></div><div><div><div><div></div><div><figure><div><div><span><img></span></div></div></figure></div><div><figure><div><div><span><img></span></div></div></figure></div></div><div><figcaption><em>text</em></figcaption><cite>text</cite></div></div></div><div><p>text</p></div><div><p>text<a>text</a>text</p></div><div><h5><a>text</a></h5></div><div><h3>text</h3></div><div><div><a><span><img></span></a><a><span><img></span></a><div><div><h3><a>text</a></h3></div><div><span>texttext</span></div><p>text<br></p><div><a>text</a><a>text</a><a>text</a></div></div></div></div><div><p><small><em><strong>text</strong>text<strong>text</strong>text<strong>text</strong>text<strong>text</strong>text</em></small></p></div><div><p>text</p></div><div><p>text</p></div><div><div><div><div></div><div><figure><div><div><span><img></span></div></div></figure></div><div><figure><div><div><span><img></span></div></div></figure></div></div><div><figcaption><em>text</em></figcaption><cite>text</cite></div></div></div><div><p>text<a>text</a>text</p></div><div><h5><a>text</a></h5></div><div><h3>text</h3></div><div><div><a><span><img></span></a><a><span><img></span></a><div><div><h3><a>text</a></h3><div><span>texttext</sp ...
# https://www.theverge.com/21345733/best-noise-canceling-headphones
#
# <[document]><html><head>text<title>text</title></head><body><div><div><div><svg><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><polygon></polygon></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path></symbol><symbol><rect></rect><rect></rect><defs><pattern><use></use></pattern></defs></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><g><path></path><path></path><path></path><path></path></g></symbol><symbol><g><path></path><path></path></g><defs><clippath><rect></rect></clippath></defs></symbol><symbol><path></path><path></path></symbol><symbol><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path></symbol><symbol><g><polygon></polygon><polygon></polygon></g></symbol><symbol><path></path><path></path></symbol><symbol><polygon></polygon></symbol><symbol><polygon></polygon></symbol><symbol><path></path></symbol><symbol><path></path><rect></rect></symbol><symbol><path></path><rect></rect></symbol><symbol><path></path></symbol><symbol><line></line><line></line><circle></circle></symbol><symbol><circle></circle><line></line></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path></symbol><symbol><g><path></path><path></path><path></path><path></path></g><defs><clippath><rect></rect></clippath></defs></symbol><symbol><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><g><path></path><path></path><path></path></g></symbol><symbol><path></path><path></path><circle></circle></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><g><g><path></path></g></g></symbol><symbol><path></path></symbol></svg><div><div><span>text</span><div></div></div></div><nav><span><a>text</a></span><span><a>text</a></span><span><a>t ...
# https://www.cnet.com/tech/mobile/best-noise-canceling-headphones/
#
# <[document]><html><head><title>text</title></head><body><div><div><div><div><div><div></div><div><div></div><input><div></div><div></div></div><div><a>text</a><button>text</button><button>text</button><div><button></button><div><div><div><button>text</button><button>text</button></div><div><a>text</a></div><div><div><span>text</span><select><option>text</option><option>text</option><option>text</option><option>text</option><option>text</option><option>text</option><option>text</option><option>text</option></select><select><option>text</option></select></div></div></div></div></div></div></div></div><div><div><div><div><a></a></div><ul><div><li><a><span>text</span><span></span></a><div><a><div></div><span>text<br>text<span>text</span></span><span></span><div></div></a><a><div></div><span>text<br>text<span>text</span></span><span></span><div></div></a><a><div></div><span>text<br>text<span>text</span></span><span></span><div></div></a><a><div></div><span>text<br>text<span>text</span></span><span></span></a><a><div></div><span>text<br>text<span>text</span></span><span></span></a><a><div></div><span>text<br>text<span>text</span></span><span></span></a><a><div></div><span>text<br>text<span>text</span></span><span></span></a><a><div></div><span>text<br>text<span>text</span></span><span></span></a><a><div></div><span>text<br>text<span>text</span></span><span></span></a><a><div></div><span>text<br>text<span>text</span></span><span></span></a><a><div></div><span>text<br>text<span>text</span></span><span></span></a><a><div></div><span>text<br>text<span>text</span></span><span></span></a></div></li></div><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></div></div></div><div></div></div></div><div><div>text<button></button></div><div><div><div><div><span></span></div><div><div><div><a>text</a><div><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a></div></div></div></div><div><span></span></div></div></div></div><div><div><div><div><span></span></div><div><div><div><a>text</a><div><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a></div></div></div></div><div><span></span></div></div></div></div><div><div><div><div><span></span></div><div><div><div><a>text</a><div><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a></div></div></div></div><div><span></span></div></div></div></div><div><div><div><div><div><div>text</div></div></div><div><div>text</div>text<a>text</a>text</div></div><div><div><img></div><div>text<br><a>text</a></div></div></div></div><div>text<a>text</a>text</div><div><ol><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><span>text</span></li></ol></div></div><div><div><ol><li>text</li><li><a>text</a></li><li><a>text</a><ol></ol></li><li><a>text</a><ol></ol></li><li><a>text</a><ol></ol></li><li><a>text</a><ol></ol></li><li><a>text</a><ol></ol></li><li><a>text</a><ol></ol></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ol></div><a></a><div><div><div><h1><span>text</span><span>text</span></h1><div>text<span>text</span><div><span>text<a>text</a></span></div></div><div></div><div><div></div></div></div></div><div><img><div><p>text</p><p>text<a>text</a>text<a>text</a>text<a>text</a>text</p></div></div><div><br><ol><li><a></a><h2>text</h2><div><div><a><div><div><img></div></div><div><div><img></div></div><div><div><img></div></div><div><div><img></div></div><div><div><img></div></div></a></div><div><div><a>text</a><a>text<span></span></a></div><img><div><span><a><div>text</div><span>text</span></a></span><br ...
# https://www.rtings.com/headphones/reviews/best/by-feature/active-noise-cancelling

# %%
list_of_urls.remove('https://support.spotify.com/us/article/premium-plans/')
list_of_urls
# Out:
# ['https://www.tomsguide.com/face-off/spotify-free-vs-premium',
#  'https://www.soundguys.com/free-spotify-vs-spotify-premium-36632/',
#  'https://www.headphonesty.com/2021/08/spotify-free-vs-premium/',
#  'https://history-computer.com/spotify-free-vs-premium-comparison-whats-the-difference/',
#  'https://www.cnet.com/tech/services-and-software/good-reasons-to-pay-for-spotify/',
#  'https://www.geeky-gadgets.com/whats-difference-between-spotify-free-and-premium/',
#  'https://blog.tunemymusic.com/spotify-free-vs-premium-a-full-comparison/',
#  'https://www.howtogeek.com/350288/spotify-free-vs-premium-is-it-worth-upgrading/',
#  'https://www.makeuseof.com/spotify-free-vs-spotify-premium-main-differences/']

# %%
html_templates= ''
i= 100
for url in list_of_urls[:8]:
    template= html_tag_extractor.extract_html_template(url)
    if template:
        print(template)
        print(url)
        print()
        html_templates+=template+'\n'
        with open(f'dummy_files/template-{i}.html', 'w') as f:
            f.write(url+template)
        i+=1
# Out:
# <[document]><html><head>text<title>text</title>texttexttexttexttexttexttexttexttexttext</head><body>text<a>text</a>text<nav><input><input><div><div><label><span>text</span></label><label><span>text</span></label><div><a><span><svg><title>text</title><g><g><g><g><path></path><path></path><path></path><path></path><path></path><path></path><path></path><polygon></polygon><path></path><path></path></g></g></g></g></svg></span><span>text</span><span></span></a></div><input><label><span>text</span><span><svg><path></path></svg></span></label><form><label>text</label><input><button><span><svg><path></path></svg></span></button></form><div><div>text<span><svg><path></path></svg></span></div></div><div><a><abbr>text</abbr></a></div><div><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><path></path><path></path></svg></a></div><div><div><button><span>text</span><div><figure><div><div><img></div></div></figure></div><div></div></button><div><div><div><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a></div></div></div></div></div></div></div><div><div><aside><div><div><a><div>text</div></a><div><a><img></a><div><div><div>text</div><ul><li>text</li><li>text</li><li>text</li></ul></div><div><div><a><div><span>text</span><span>text</span></div></a></div><a>text</a></div></div></div></div></div></aside></div></div><div><div><ul><li><a><i></i></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li>text<i></i><i></i><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></li></ul><div><div><a>text</a></div></div></div></div></nav><div><div></div></div><div></div><div><div><div><nav><span>text</span><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></nav></div></div><div></div><div><aside><p>text<a>text</a>text</p></aside></div><div></div><article><header><nav><ol><li><a>text</a></li><li><a>text</a></li></ol></nav><h1>text</h1><div><div><div><div><div>text<span><a>text</a></span></div><span>text<span><span><time>text</time></span></span></span></div></div></div><p>text</p><nav><ul><li><a><svg><circle></circle><path></path></svg></a></li><li><a><svg><circle></circle><path></path></svg></a></li><li><a><svg><path></path></svg></a></li><li><a><i></i></a></li><li><a><svg><circle></circle><path></path></svg></a></li><li><a><svg><path></path><path></path></svg></a></li><li><a><i></i></a></li></ul><a><i></i><span>text</span></a></nav></div></header><section><div><div><div><div><picture><source></source><source></source><img></picture></div></div></div><figcaption><span>text</span></figcaption></div><div></div><div><p><strong>text</strong>text<a>text</a>text</p><div></div><figure><div><div><p><picture><source></source><source></source><img></picture></p></div></div><figcaption><span>text</span></figcaption></figure><p>t ...
# https://www.tomsguide.com/face-off/spotify-free-vs-premium
#
# <[document]><html><head><title>text</title></head><body><div><header><div><button><svg><path></path></svg></button></div><div></div><a><svg><path></path></svg></a><a>text<svg><path></path></svg></a><button><svg><path></path><path></path></svg><svg><path></path></svg></button><button><svg><path></path><path></path><path></path></svg></button></header><div></div><div><div></div></div><main><div><p>text<a>text</a></p></div><div><div><a>text</a></div><div><h1>text</h1><div>text</div></div><div><div><div><span>text</span><button>text</button><div></div></div><div>text</div><div>text</div></div><div><button><svg><path></path></svg></button><a><svg><path></path></svg></a><a><svg><path></path></svg></a></div></div><div><div><div></div></div></div><div></div><div><div><div><p><a><span>text</span></a><span>text</span><span>text</span><span>text<a>text</a>text</span></p></div><div><p><em>text<br></em></p></div><span><div></div></span><div><h2><strong>text</strong></h2></div><a><div><picture><source></source><img></picture><div></div><div>text</div></div></a><div><p><span>text</span></p></div><div><q>text</q></div><div><p><span>text</span><i><span>text</span></i><span>text<br></span></p></div><div><p><span>text</span><i><span>text</span></i><span>text</span></p><h3>text</h3><p><span>text</span>text</p><h3>text</h3></div><a><div><picture><source></source><img></picture><div></div><div>text</div></div></a><div><p><span>text<a>text</a>text</span></p></div><div><div></div></div><div><div></div></div><div><p><span>text</span></p></div><div><div></div></div><span><div></div></span><div></div><div><h2><strong>text</strong></h2></div><a><div><picture><source></source><img></picture><div></div><div>text</div></div></a><div><p><span>text<a>text</a>text</span>text<a>text</a>text</p></div><div><q>text</q></div><div><p><span>text</span></p></div><div><p><span>text</span></p></div><div><div></div></div><div><button>text<svg><path></path></svg></button><div><div><div><p>text<a>text</a>text</p></div></div></div></div><span><div></div></span><div><h2><strong>text</strong></h2><p><span>text</span></p></div><div><p><span>text</span></p></div><div><q>text</q></div><div><p><span>text</span></p></div><div><p><span>text</span></p></div><div><div></div></div><span><div></div></span><div><h2><strong>text</strong></h2></div><a><div><picture><source></source><img></picture><div></div><div>text</div></div></a><div><p><span>text</span></p><h3>text</h3><p><span>text</span></p></div><div><p><span>text</span></p><h3>text</h3><p><span>text</span></p></div><div><p><span>text</span></p></div><span><div></div></span><div><h2><strong>text</strong></h2><p><span>text</span></p></div><div><p><span></span></p></div><div><table><thead><tr><th>text</th><th>text</th></tr></thead><tbody><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr></tbody></table></div><span><div></div></span><di ...
# https://www.soundguys.com/free-spotify-vs-spotify-premium-36632/
#
# <[document]><html><head><title>text</title></head><body><header><div><div><div><a><svg><g><path></path><path></path><path></path></g></svg></a></div><div><a><svg><g><path></path><circle></circle><path></path><path></path><path></path><g><path></path></g><path></path><path></path><g><path></path><path></path></g><path></path></g></svg><svg><path></path></svg></a></div><div><nav><div><div><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></div></div><div><a><svg><g><circle></circle><path></path><path></path></g></svg></a></div></nav></div><div><div><form><div><a><svg><path></path></svg></a></div><div><input></div><div><button><svg><g><circle></circle><path></path><path></path></g></svg></button></div></form></div></div></div></div><a><svg><path></path></svg></a><div><div><ul><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg><ul><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li></ul></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg><ul><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li></ul></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg><ul><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li></ul></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></ ...
# https://www.headphonesty.com/2021/08/spotify-free-vs-premium/
#
# <[document]><html><head><title>text</title></head><body><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><div><header><div><nav><div><a><img></a><a><img></a><div><div><span>text</span><button></button></div><div><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></div></div><div><div><div><form><input><button><svg><path></path></svg><span>text</span></button></form></div></div><button><svg><path></path></svg><span>text</span></button><button><svg><path></path></svg><span>text</span></button></div></div></nav><div><div><div><div><p>text</p><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a></div></div></div></div><div><div><form><input><button><svg><path></path></svg><span>text</span></button></form></div></div></div></header><div><div><div><a>text</a><p>text</p><a>text</a><p>text</p><p>text</p></div><div><div><main><header><div><img></div><div><div><p>text</p><a>text</a><a>text</a></div></div><h1>text</h1><p><small>text<time>text</time><span>text<span><a>text</a></span></span></small></p></header><div><p><a>text</a>text<a>text</a>text</p><p>text</p><h2>text</h2><p>text</p><figure><table><thead><tr><th><strong>text</strong></th><th><strong>text</strong></th><th><strong>text</strong></th></tr></thead><tbody><tr><td>text</td><td>text<br>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr></tbody></table></figure><div><div><div><div>text</div><div><a>text</a><div><div><span></span><span>text</span></div><i></i></div><div></div><div><ul><li>text</li><li>text</li><li>text</li><li>text</li><li>text</li></ul></div></div><div><a><img></a></div><div><a>text</a></div><div></div><div><div><span>text</span></div></div><div><div>text<i></i></div></div></div></div></div><h2>text</h2><p>text</p><h3>text</h3><p>text<a>text</a>text</p><h3>text</h3><p>te ...
# https://history-computer.com/spotify-free-vs-premium-comparison-whats-the-difference/
#
# <[document]><html><head>text<title>text</title></head><body><div><div><div><svg><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><polygon></polygon></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path></symbol><symbol><rect></rect><rect></rect><defs><pattern><use></use></pattern></defs></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><g><path></path><path></path><path></path><path></path></g></symbol><symbol><g><path></path><path></path></g><defs><clippath><rect></rect></clippath></defs></symbol><symbol><path></path><path></path></symbol><symbol><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path></symbol><symbol><g><polygon></polygon><polygon></polygon></g></symbol><symbol><path></path><path></path></symbol><symbol><polygon></polygon></symbol><symbol><polygon></polygon></symbol><symbol><path></path></symbol><symbol><path></path><rect></rect></symbol><symbol><path></path><rect></rect></symbol><symbol><path></path></symbol><symbol><line></line><line></line><circle></circle></symbol><symbol><circle></circle><line></line></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path></symbol><symbol><g><path></path><path></path><path></path><path></path></g><defs><clippath><rect></rect></clippath></defs></symbol><symbol><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><g><path></path><path></path><path></path></g></symbol><symbol><path></path><path></path><circle></circle></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><g><g><path></path></g></g></symbol><symbol><path></path></symbol></svg><div><div><span>text</span><div></div></div></div><nav><span><a>text</a></span><spa ...
# https://www.cnet.com/tech/services-and-software/good-reasons-to-pay-for-spotify/
#
# <[document]><html><head>text<title>text</title>texttexttexttexttexttexttext<div></div>texttexttexttexttexttexttexttexttexttext</head><body><div><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul><header><div><div><p><a>text</a></p><p>text</p></div></div></header><nav><div><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></div></nav>text<br><div>text<div></div></div><br>texttexttext<div><div><main><article><header><h1>text</h1><p><time>text</time><time>text</time>text<span><a><span>text</span></a></span></p></header><div><p><img></p><div>text<div></div></div><p>text<a>text</a>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><h3>text</h3><p>text<a>text</a>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><h3>text</h3><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><h3>text</h3><p>text</p><p>text</p><p>text</p><p>text<a>text</a>text</p><p>text<span><a>text</a></span></p><ul><li><a><div><svg><path></path></svg><span>text</span></div></a></li><li><a><div><svg><path></path></svg><span>text</span></div></a></li><li><a><div><svg><path></path></svg><span>text</span></div></a></li><li><a><div><svg><path></path></svg><span>text</span></div></a></li></ul>text<div></div><p></p><span>text<a>text</a>text<a>text</a></span><p><br><b>text</b><div></div><br><b>text</b>text<a>text</a>text</p></div><footer></footer></article><div></div></main><aside><h2>text</h2><section><div><ul><li><a><svg><title>text</title><use></use></svg></a></li><li><a><svg><title>text</title><use></use></svg></a></li><li><a><svg><title>text</title><use></use></svg></a></li><li><a><svg><title>text</title><use></use></svg></a></li></ul></div></section><section><div><form><label>text</label><input><input></form></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article></div></section><section><div><div>text<div></div></div></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a ...
# https://www.geeky-gadgets.com/whats-difference-between-spotify-free-and-premium/
#
# <[document]><html><head><title>text</title>texttexttext</head><body><a>text</a><div><header><div><div><div><div><div><a><svg><path></path><path></path><path></path><defs><lineargradient><stop></stop><stop></stop><stop></stop></lineargradient><lineargradient><stop></stop><stop></stop></lineargradient></defs></svg></a></div></div></div></div><div><div><div><div><nav><ul><li><a>text</a></li></ul></nav><div><i></i><i></i><span>text</span></div><nav><ul><li><a>text</a></li></ul></nav></div></div><div><div><div><a><span><span>text</span></span></a></div></div></div></div></div><div><div><div><div><div><div><ul><li><a><img><span>text</span></a><ul></ul></li></ul></div></div></div></div></div></div></div></header></div><div><section><div></div><div><main><div><div><div><h1>text</h1></div></div><div><div>text</div></div><div><div><img></div></div><section><div><div><div><div><div><ul><li><span><i></i></span><span>text</span></li><li><a><span>text</span></a></li><li><span><i></i></span><span>text</span></li></ul></div></div><div><div><ul><li><span><i></i></span><span>text</span></li><li><span><i></i></span><span>text</span></li></ul></div></div></div></div><div><div><div><div><div><div><div><span><i></i></span></div></div><div><div><span><i></i></span></div></div></div></div></div></div></div></div></section><div><div><div><span></span></div></div></div><div><div><p>text</p><p>text</p><p>text</p><p></p><ul><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li></ul><p></p><p>text<a>text</a>text</p><p></p><h2>text</h2><p>text<a>text</a>text</p><p>text<a>text</a>text</p><p>text</p><p>text</p><h2>text</h2><p>text</p><p>text</p><p>text</p><p>text</p><div><figure><img><figcaption><strong><em>text</em></strong></figcaption></figure></div><p>text</p><p>text</p><p>text</p><h2>text</h2><p>text</p><p>text</p><p>text</p><div><figure><img></figure></div><h2>text</h2><p>text</p><figure><table><thead><tr><th></th><th>text</th><th>text</th></tr></thead><tbody><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text<br></td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr></tbody></table><figcaption>text</figcaption></figure><h2>text</h2><p>text</p><p>text</p><p>text</p><h2>text</h2><p>text</p><p>text</p><div><figure><img><figcaption><strong><em>text</em></strong></figcaption></figure></div><p>text</p><p>text</p><div>text<div><a>text</a></div></div><h2>text</h2><p>text</p><p>text</p><p>text</p><p>text</p><h2>text</h2><p>text</p><p>text</p><div><figure><img></figure></div><p>text</p><p>text</p><h2>text</h2><p>text<a>text</a>text</p><p>text</p><h2>text</h2><figure><table><thead><tr><th></th><th>text</th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr><tr><th>text</th><th></th><th>text</th></tr><tr><th>text</th><th></th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr><tr><th>text</th><th></th><th>text</th></tr><tr><th>text</th><th></th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr></thead></table><figcaption>text</figcaption></figure><h2>text</h2><p>text</p><p>text</p><p></p><div><figure><img></figure></div><p></p><h2>text</h2><p>text<a>text</a>text</p><p>text<a>text</a>text<a>text</a>text<a>text</a>text<a>text</a>text<a>text</a>text<a>text</a>text</p></div></div></div></main></div></section></div><div><footer><div><div><div><se ...
# https://blog.tunemymusic.com/spotify-free-vs-premium-a-full-comparison/
#
# <[document]><html><head>texttexttexttext<title>text</title>texttexttexttexttexttexttext</head><body>text<div></div><header><h1>text</h1><div><div><div><div></div><div></div></div><div><a><picture><source></source><img></picture></a></div><div><div><a>text</a></div></div></div></div><nav><div><span>text</span><span><a>text</a></span><span><a>text</a></span><span><a>text</a></span><span><a>text</a></span><span><a>text</a></span><span><a>text</a></span></div></nav><div><div><div></div><div></div></div><nav><ul><li><ul><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><ul><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li></ul></li></ul><ul><li><span></span><a><span>text</span></a></li><li><span></span><a><span>text</span></a></li><li><span></span><a><span>text</span></a></li></ul><ul><li><a></a></li><li><a></a></li><li><a></a></li><li><a></a></li><li><a></a></li><li><a></a></li><li><a></a></li></ul></nav><footer><nav><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></nav><div></div><div>text</div></footer></div></header><div><div></div><div><form><input></form></div></div>texttexttexttext<main><article><header><div><nav><ul><li><a>text</a></li><li><a>text</a></li></ul></nav></div><h1>text</h1><div><div><span>text</span><a>text</a><span></span><span>text</span><a>text</a></div><span>text<time>text</time></span></div><div></div><p>text</p><div><figure><picture>text<source><source></source><source></source><source></source>text<img></source></picture><figcaption></figcaption></figure></div>text</header><section><div>texttext<span>text<a>text</a></span></div>texttext<div><div><h3>text</h3><ul><li><a>text</a></li></ul><ul><li><a>text</a></li></ul><ul><li><a>text</a></li></ul></div><p>text</p>texttexttexttexttext<h2>text</h2><div><div><figure><picture>text<source></source><source></source><source></source><source></source>text<img></picture></figure></div></div>texttexttexttext<p>text<a>text</a>text</p>texttext<p>text</p>texttext<p>text</p>texttext<ul><li>text</li><li>text</li><li>text</li><li>text</li></ul>texttexttexttext<div><div><figure><picture>text<source></source><source></source><source></source><source></source>text<img></picture></figure></div></div>texttext<p>text</p>texttext<p>text<a>text</a>text</p>texttext<p><span>text<a>text</a></span></p>texttext<div>text</div>texttext<h2>text</h2><p>text</p>texttext<ul><li><strong>text</strong>text</li><li><a><strong>text</strong></a>text</li><li><strong>text</strong>text</li><li><strong>text</strong>text</li></ul>texttexttexttex ...
# https://www.howtogeek.com/350288/spotify-free-vs-premium-is-it-worth-upgrading/

# %%
from main import generate_intent_v2

generate_intent_v2("spotify free vs premium")
# Out:
# Spotify Free vs. Premium: Should you pay to play? www.tomsguide.com https://www.tomsguide.com/face-off/spotify-free-vs-premium Arguably the biggest difference between Spotify's Free and Premium tiers is the latter's complete lack of ads. That goes for both the visual ads ... Spotify Free vs Premium: Is it worth it? www.soundguys.com https://www.soundguys.com/free-spotify-vs-spotify-premium-36632/ First, there is the Spotify Premium Individual subscription, which is $9.99/month. This allows access to all the Premium features such as no ad interruptions, ... Spotify Free vs. Premium Comparison: What's the Difference? history-computer.com https://history-computer.com/spotify-free-vs-premium-comparison-whats-the-difference/ Spotify Free is completely free, while Premium costs $9.99 per month. There are also three other plans: $15.99/month for a family plan (up to ... Spotify Premium vs. Free: 6 Good Reasons to Pay www.cnet.com https://www.cnet.com/tech/services-and-software/good-reasons-to-pay-for-spotify/ Spotify Premium adds Very High quality streaming at 320 Kbps, which can make for better, more detailed audio output if you use high-end ... Spotify Free vs. Premium: Should You Upgrade? www.headphonesty.com https://www.headphonesty.com/2021/08/spotify-free-vs-premium/ Spotify Free is the platform's free plan. It gives you access to the entire library of content but comes with ads and limitations, which we'll ... Premium plans - Spotify support.spotify.com https://support.spotify.com/us/article/premium-plans/ 6 people living together each get their own Premium account for 1 discount price. Premium Family comes with: Spotify Kids - an app packed with singalongs, ... What's the difference between Spotify Free and Premium www.geeky-gadgets.com https://www.geeky-gadgets.com/whats-difference-between-spotify-free-and-premium/ The Premium version comes with unlimited skips, unlike the free version and it also comes with higher-quality audio. On the free version, music ... Spotify Free VS Premium: Should I Pay or Stay Free in 2023? www.viwizard.com https://www.viwizard.com/spotify-music-tips/spotify-free-vs-premium.html Spotify Premium isn't just about ad-free music and better quality. It goes further, offering exclusive features not available to Spotify Free ... Spotify Free vs Premium vs Family: Which One is the Best ... www.noteburner.com https://www.noteburner.com/spotify-music-tips/spotify-free-vs-premium-vs-family.html Spotify offers users free trials of Premium features for 30 days. And it increases the bitrate for some songs. So just pay $9.99 per month, the Premium users ... Spotify Free vs Premium: A Full Comparison blog.tunemymusic.com https://blog.tunemymusic.com/spotify-free-vs-premium-a-full-comparison/ If you're looking for something gratis, then the Spotify Free Plan might be right for you. It is entirely free. You will need to download the ...
# spotify free vs premium:
#  tensor([[0.8628],
#         [0.8656],
#         [0.8425],
#         [0.8482],
#         [0.8333]])
# ('navigational',
#  0.8656492233276367,
#  tensor([[0.8628],
#          [0.8656],
#          [0.8425],
#          [0.8482],
#          [0.8333]]))

# %%
print(html_templates)
# Out:
# <[document]><html><head>text<title>text</title>texttexttexttexttexttexttexttexttexttext</head><body>text<a>text</a>text<nav><input><input><div><div><label><span>text</span></label><label><span>text</span></label><div><a><span><svg><title>text</title><g><g><g><g><path></path><path></path><path></path><path></path><path></path><path></path><path></path><polygon></polygon><path></path><path></path></g></g></g></g></svg></span><span>text</span><span></span></a></div><input><label><span>text</span><span><svg><path></path></svg></span></label><form><label>text</label><input><button><span><svg><path></path></svg></span></button></form><div><div>text<span><svg><path></path></svg></span></div></div><div><a><abbr>text</abbr></a></div><div><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><path></path><path></path></svg></a></div><div><div><button><span>text</span><div><figure><div><div><img></div></div></figure></div><div></div></button><div><div><div><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a></div></div></div></div></div></div></div><div><div><aside><div><div><a><div>text</div></a><div><a><img></a><div><div><div>text</div><ul><li>text</li><li>text</li><li>text</li></ul></div><div><div><a><div><span>text</span><span>text</span></div></a></div><a>text</a></div></div></div></div></div></aside></div></div><div><div><ul><li><a><i></i></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li>text<i></i><i></i><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></li></ul><div><div><a>text</a></div></div></div></div></nav><div><div></div></div><div></div><div><div><div><nav><span>text</span><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></nav></div></div><div></div><div><aside><p>text<a>text</a>text</p></aside></div><div></div><article><header><nav><ol><li><a>text</a></li><li><a>text</a></li></ol></nav><h1>text</h1><div><div><div><div><div>text<span><a>text</a></span></div><span>text<span><span><time>text</time></span></span></span></div></div></div><p>text</p><nav><ul><li><a><svg><circle></circle><path></path></svg></a></li><li><a><svg><circle></circle><path></path></svg></a></li><li><a><svg><path></path></svg></a></li><li><a><i></i></a></li><li><a><svg><circle></circle><path></path></svg></a></li><li><a><svg><path></path><path></path></svg></a></li><li><a><i></i></a></li></ul><a><i></i><span>text</span></a></nav></div></header><section><div><div><div><div><picture><source></source><source></source><img></picture></div></div></div><figcaption><span>text</span></figcaption></div><div></div><div><p><strong>text</strong>text<a>text</a>text</p><div></div><figure><div><div><p><picture><source></source><source></source><img></picture></p></div></div><figcaption><span>text</span></figcaption></figure><p>t ...
# <[document]><html><head><title>text</title></head><body><div><header><div><button><svg><path></path></svg></button></div><div></div><a><svg><path></path></svg></a><a>text<svg><path></path></svg></a><button><svg><path></path><path></path></svg><svg><path></path></svg></button><button><svg><path></path><path></path><path></path></svg></button></header><div></div><div><div></div></div><main><div><p>text<a>text</a></p></div><div><div><a>text</a></div><div><h1>text</h1><div>text</div></div><div><div><div><span>text</span><button>text</button><div></div></div><div>text</div><div>text</div></div><div><button><svg><path></path></svg></button><a><svg><path></path></svg></a><a><svg><path></path></svg></a></div></div><div><div><div></div></div></div><div></div><div><div><div><p><a><span>text</span></a><span>text</span><span>text</span><span>text<a>text</a>text</span></p></div><div><p><em>text<br></em></p></div><span><div></div></span><div><h2><strong>text</strong></h2></div><a><div><picture><source></source><img></picture><div></div><div>text</div></div></a><div><p><span>text</span></p></div><div><q>text</q></div><div><p><span>text</span><i><span>text</span></i><span>text<br></span></p></div><div><p><span>text</span><i><span>text</span></i><span>text</span></p><h3>text</h3><p><span>text</span>text</p><h3>text</h3></div><a><div><picture><source></source><img></picture><div></div><div>text</div></div></a><div><p><span>text<a>text</a>text</span></p></div><div><div></div></div><div><div></div></div><div><p><span>text</span></p></div><div><div></div></div><span><div></div></span><div></div><div><h2><strong>text</strong></h2></div><a><div><picture><source></source><img></picture><div></div><div>text</div></div></a><div><p><span>text<a>text</a>text</span>text<a>text</a>text</p></div><div><q>text</q></div><div><p><span>text</span></p></div><div><p><span>text</span></p></div><div><div></div></div><div><button>text<svg><path></path></svg></button><div><div><div><p>text<a>text</a>text</p></div></div></div></div><span><div></div></span><div><h2><strong>text</strong></h2><p><span>text</span></p></div><div><p><span>text</span></p></div><div><q>text</q></div><div><p><span>text</span></p></div><div><p><span>text</span></p></div><div><div></div></div><span><div></div></span><div><h2><strong>text</strong></h2></div><a><div><picture><source></source><img></picture><div></div><div>text</div></div></a><div><p><span>text</span></p><h3>text</h3><p><span>text</span></p></div><div><p><span>text</span></p><h3>text</h3><p><span>text</span></p></div><div><p><span>text</span></p></div><span><div></div></span><div><h2><strong>text</strong></h2><p><span>text</span></p></div><div><p><span></span></p></div><div><table><thead><tr><th>text</th><th>text</th></tr></thead><tbody><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr><tr><td><div>text<br></div></td><td><div>text<br></div></td></tr></tbody></table></div><span><div></div></span><di ...
# <[document]><html><head><title>text</title></head><body><header><div><div><div><a><svg><g><path></path><path></path><path></path></g></svg></a></div><div><a><svg><g><path></path><circle></circle><path></path><path></path><path></path><g><path></path></g><path></path><path></path><g><path></path><path></path></g><path></path></g></svg><svg><path></path></svg></a></div><div><nav><div><div><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></div></div><div><a><svg><g><circle></circle><path></path><path></path></g></svg></a></div></nav></div><div><div><form><div><a><svg><path></path></svg></a></div><div><input></div><div><button><svg><g><circle></circle><path></path><path></path></g></svg></button></div></form></div></div></div></div><a><svg><path></path></svg></a><div><div><ul><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg><ul><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li></ul></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg><ul><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li></ul></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg><ul><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li></ul></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></svg><svg><g><path></path><path></path><path></path></g></svg></li><li><a>text</a><svg><g><path></path><path></path><path></path></g></ ...
# <[document]><html><head><title>text</title></head><body><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><svg><defs><filter><fecolormatrix></fecolormatrix><fecomponenttransfer><fefuncr></fefuncr><fefuncg></fefuncg><fefuncb></fefuncb><fefunca></fefunca></fecomponenttransfer><fecomposite></fecomposite></filter></defs></svg><div><header><div><nav><div><a><img></a><a><img></a><div><div><span>text</span><button></button></div><div><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></div></div><div><div><div><form><input><button><svg><path></path></svg><span>text</span></button></form></div></div><button><svg><path></path></svg><span>text</span></button><button><svg><path></path></svg><span>text</span></button></div></div></nav><div><div><div><div><p>text</p><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a><a>text</a></div></div></div></div><div><div><form><input><button><svg><path></path></svg><span>text</span></button></form></div></div></div></header><div><div><div><a>text</a><p>text</p><a>text</a><p>text</p><p>text</p></div><div><div><main><header><div><img></div><div><div><p>text</p><a>text</a><a>text</a></div></div><h1>text</h1><p><small>text<time>text</time><span>text<span><a>text</a></span></span></small></p></header><div><p><a>text</a>text<a>text</a>text</p><p>text</p><h2>text</h2><p>text</p><figure><table><thead><tr><th><strong>text</strong></th><th><strong>text</strong></th><th><strong>text</strong></th></tr></thead><tbody><tr><td>text</td><td>text<br>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr></tbody></table></figure><div><div><div><div>text</div><div><a>text</a><div><div><span></span><span>text</span></div><i></i></div><div></div><div><ul><li>text</li><li>text</li><li>text</li><li>text</li><li>text</li></ul></div></div><div><a><img></a></div><div><a>text</a></div><div></div><div><div><span>text</span></div></div><div><div>text<i></i></div></div></div></div></div><h2>text</h2><p>text</p><h3>text</h3><p>text<a>text</a>text</p><h3>text</h3><p>te ...
# <[document]><html><head>text<title>text</title></head><body><div><div><div><svg><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><polygon></polygon></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path></symbol><symbol><rect></rect><rect></rect><defs><pattern><use></use></pattern></defs></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><g><path></path><path></path><path></path><path></path></g></symbol><symbol><g><path></path><path></path></g><defs><clippath><rect></rect></clippath></defs></symbol><symbol><path></path><path></path></symbol><symbol><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path></symbol><symbol><g><polygon></polygon><polygon></polygon></g></symbol><symbol><path></path><path></path></symbol><symbol><polygon></polygon></symbol><symbol><polygon></polygon></symbol><symbol><path></path></symbol><symbol><path></path><rect></rect></symbol><symbol><path></path><rect></rect></symbol><symbol><path></path></symbol><symbol><line></line><line></line><circle></circle></symbol><symbol><circle></circle><line></line></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path></symbol><symbol><g><path></path><path></path><path></path><path></path></g><defs><clippath><rect></rect></clippath></defs></symbol><symbol><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path><path></path><path></path></symbol><symbol><path></path><path></path><path></path><path></path><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><g><path></path><path></path><path></path></g></symbol><symbol><path></path><path></path><circle></circle></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><path></path></symbol><symbol><g><g><path></path></g></g></symbol><symbol><path></path></symbol></svg><div><div><span>text</span><div></div></div></div><nav><span><a>text</a></span><spa ...
# <[document]><html><head>text<title>text</title>texttexttexttexttexttexttext<div></div>texttexttexttexttexttexttexttexttexttext</head><body><div><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul><header><div><div><p><a>text</a></p><p>text</p></div></div></header><nav><div><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></div></nav>text<br><div>text<div></div></div><br>texttexttext<div><div><main><article><header><h1>text</h1><p><time>text</time><time>text</time>text<span><a><span>text</span></a></span></p></header><div><p><img></p><div>text<div></div></div><p>text<a>text</a>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><h3>text</h3><p>text<a>text</a>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><h3>text</h3><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><p>text</p><h3>text</h3><p>text</p><p>text</p><p>text</p><p>text<a>text</a>text</p><p>text<span><a>text</a></span></p><ul><li><a><div><svg><path></path></svg><span>text</span></div></a></li><li><a><div><svg><path></path></svg><span>text</span></div></a></li><li><a><div><svg><path></path></svg><span>text</span></div></a></li><li><a><div><svg><path></path></svg><span>text</span></div></a></li></ul>text<div></div><p></p><span>text<a>text</a>text<a>text</a></span><p><br><b>text</b><div></div><br><b>text</b>text<a>text</a>text</p></div><footer></footer></article><div></div></main><aside><h2>text</h2><section><div><ul><li><a><svg><title>text</title><use></use></svg></a></li><li><a><svg><title>text</title><use></use></svg></a></li><li><a><svg><title>text</title><use></use></svg></a></li><li><a><svg><title>text</title><use></use></svg></a></li></ul></div></section><section><div><form><label>text</label><input><input></form></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article></div></section><section><div><div>text<div></div></div></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article></div></section><section><div><h3>text</h3><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a><img></a><header><h4><a>text</a></h4></header></article><article><a ...
# <[document]><html><head><title>text</title>texttexttext</head><body><a>text</a><div><header><div><div><div><div><div><a><svg><path></path><path></path><path></path><defs><lineargradient><stop></stop><stop></stop><stop></stop></lineargradient><lineargradient><stop></stop><stop></stop></lineargradient></defs></svg></a></div></div></div></div><div><div><div><div><nav><ul><li><a>text</a></li></ul></nav><div><i></i><i></i><span>text</span></div><nav><ul><li><a>text</a></li></ul></nav></div></div><div><div><div><a><span><span>text</span></span></a></div></div></div></div></div><div><div><div><div><div><div><ul><li><a><img><span>text</span></a><ul></ul></li></ul></div></div></div></div></div></div></div></header></div><div><section><div></div><div><main><div><div><div><h1>text</h1></div></div><div><div>text</div></div><div><div><img></div></div><section><div><div><div><div><div><ul><li><span><i></i></span><span>text</span></li><li><a><span>text</span></a></li><li><span><i></i></span><span>text</span></li></ul></div></div><div><div><ul><li><span><i></i></span><span>text</span></li><li><span><i></i></span><span>text</span></li></ul></div></div></div></div><div><div><div><div><div><div><div><span><i></i></span></div></div><div><div><span><i></i></span></div></div></div></div></div></div></div></div></section><div><div><div><span></span></div></div></div><div><div><p>text</p><p>text</p><p>text</p><p></p><ul><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li><li><a><strong>text</strong></a></li></ul><p></p><p>text<a>text</a>text</p><p></p><h2>text</h2><p>text<a>text</a>text</p><p>text<a>text</a>text</p><p>text</p><p>text</p><h2>text</h2><p>text</p><p>text</p><p>text</p><p>text</p><div><figure><img><figcaption><strong><em>text</em></strong></figcaption></figure></div><p>text</p><p>text</p><p>text</p><h2>text</h2><p>text</p><p>text</p><p>text</p><div><figure><img></figure></div><h2>text</h2><p>text</p><figure><table><thead><tr><th></th><th>text</th><th>text</th></tr></thead><tbody><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text<br></td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr><tr><td>text</td><td>text</td><td>text</td></tr></tbody></table><figcaption>text</figcaption></figure><h2>text</h2><p>text</p><p>text</p><p>text</p><h2>text</h2><p>text</p><p>text</p><div><figure><img><figcaption><strong><em>text</em></strong></figcaption></figure></div><p>text</p><p>text</p><div>text<div><a>text</a></div></div><h2>text</h2><p>text</p><p>text</p><p>text</p><p>text</p><h2>text</h2><p>text</p><p>text</p><div><figure><img></figure></div><p>text</p><p>text</p><h2>text</h2><p>text<a>text</a>text</p><p>text</p><h2>text</h2><figure><table><thead><tr><th></th><th>text</th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr><tr><th>text</th><th></th><th>text</th></tr><tr><th>text</th><th></th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr><tr><th>text</th><th></th><th>text</th></tr><tr><th>text</th><th></th><th>text</th></tr><tr><th>text</th><th>text</th><th>text</th></tr></thead></table><figcaption>text</figcaption></figure><h2>text</h2><p>text</p><p>text</p><p></p><div><figure><img></figure></div><p></p><h2>text</h2><p>text<a>text</a>text</p><p>text<a>text</a>text<a>text</a>text<a>text</a>text<a>text</a>text<a>text</a>text<a>text</a>text</p></div></div></div></main></div></section></div><div><footer><div><div><div><se ...
# <[document]><html><head>texttexttexttext<title>text</title>texttexttexttexttexttexttext</head><body>text<div></div><header><h1>text</h1><div><div><div><div></div><div></div></div><div><a><picture><source></source><img></picture></a></div><div><div><a>text</a></div></div></div></div><nav><div><span>text</span><span><a>text</a></span><span><a>text</a></span><span><a>text</a></span><span><a>text</a></span><span><a>text</a></span><span><a>text</a></span></div></nav><div><div><div></div><div></div></div><nav><ul><li><ul><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li><li><ul><li><span>text</span><span></span><ul><li><a><span>text</span></a></li><li><a><span>text</span></a></li></ul></li></ul></li></ul><ul><li><span></span><a><span>text</span></a></li><li><span></span><a><span>text</span></a></li><li><span></span><a><span>text</span></a></li></ul><ul><li><a></a></li><li><a></a></li><li><a></a></li><li><a></a></li><li><a></a></li><li><a></a></li><li><a></a></li></ul></nav><footer><nav><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></nav><div></div><div>text</div></footer></div></header><div><div></div><div><form><input></form></div></div>texttexttexttext<main><article><header><div><nav><ul><li><a>text</a></li><li><a>text</a></li></ul></nav></div><h1>text</h1><div><div><span>text</span><a>text</a><span></span><span>text</span><a>text</a></div><span>text<time>text</time></span></div><div></div><p>text</p><div><figure><picture>text<source><source></source><source></source><source></source>text<img></source></picture><figcaption></figcaption></figure></div>text</header><section><div>texttext<span>text<a>text</a></span></div>texttext<div><div><h3>text</h3><ul><li><a>text</a></li></ul><ul><li><a>text</a></li></ul><ul><li><a>text</a></li></ul></div><p>text</p>texttexttexttexttext<h2>text</h2><div><div><figure><picture>text<source></source><source></source><source></source><source></source>text<img></picture></figure></div></div>texttexttexttext<p>text<a>text</a>text</p>texttext<p>text</p>texttext<p>text</p>texttext<ul><li>text</li><li>text</li><li>text</li><li>text</li></ul>texttexttexttext<div><div><figure><picture>text<source></source><source></source><source></source><source></source>text<img></picture></figure></div></div>texttext<p>text</p>texttext<p>text<a>text</a>text</p>texttext<p><span>text<a>text</a></span></p>texttext<div>text</div>texttext<h2>text</h2><p>text</p>texttext<ul><li><strong>text</strong>text</li><li><a><strong>text</strong></a>text</li><li><strong>text</strong>text</li><li><strong>text</strong>text</li></ul>texttexttexttex ...

# %%
import openai
def generate_object_description(text, print_lists=False):

    openai.api_base = "https://openrouter.ai/api/v1"
    # openai.api_key = "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"
    openai.api_key = "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"



    response = openai.ChatCompletion.create(
            # model="anthropic/claude-2", # Optional (user controls the default)
            # model="meta-llama/codellama-34b-instruct", # Optional (user controls the default)
            model="openai/gpt-4-32k", # Optional (user controls the default)
            # model="meta-llama/llama-2-70b-chat", # Optional (user controls the default)
            messages=[
                        {"role": "user", "content": f"create a html template using structure from all of the following html templates and deduping the redundant ones:  \n{text}?"},
                    ],
                # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
                #         "X-Title": $YOUR_APP_NAME },
                headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                        "X-Title": "Deepankar" },
            )
    reply = response.choices[0].message.content
    # l= reply.content.split('\n')
    # svo_triplets= []
    # for triplet in l:
    #     triplet= triplet.replace("'", '') 
    #     triplet= triplet.replace('"', '') 
    #     triplet= triplet.replace('(', '') 
    #     triplet= triplet.replace('[', '') 
    #     triplet= triplet.replace(']', '') 
    #     triplet= triplet.replace(')', '') 
    #     triplet= triplet.strip() 
    #     triplet= triplet.split(', ') 
    #     triplet[-1]= triplet[-1].replace(',', '') 
    #     svo_triplets.append(tuple(triplet))
    
    if print_lists:
        print(reply)
    
    return reply

# %%
l= ['https://facebook.com', 'https://ig.com']

# %%
html_templates= '''
'''
m= 1
for i in l:
    template= html_tag_extractor.extract_html_template(i)
    with open(f'{m}.html', 'w') as f:
        f.write(template)
    html_templates+=template+'\n'
    m+=1

# %%
html_templates
# Out:
# '<[document]><html><head>text<title>text</title>texttexttexttexttexttexttexttexttexttext</head><body>text<a>text</a>text<nav><input><input><div><div><label><span>text</span></label><label><span>text</span></label><div><a><span><svg><title>text</title><g><g><g><g><path></path><path></path><path></path><path></path><path></path><path></path><path></path><polygon></polygon><path></path><path></path></g></g></g></g></svg></span><span>text</span><span></span></a></div><input><label><span>text</span><span><svg><path></path></svg></span></label><form><label>text</label><input><button><span><svg><path></path></svg></span></button></form><div><div>text<span><svg><path></path></svg></span></div></div><div><a><abbr>text</abbr></a></div><div><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><circle></circle><path></path></svg></a><a><svg><path></path><path></path></svg></a></div><div><div><button><span>text</span><div><figure><div><div><img></div></div></figure></div><div></div></button><div><div><div><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a><a><div><div><figure><div><div><div><div><img></div></div></div></div></figure></div><span>text</span></div><div><svg><path></path></svg></div></a></div></div></div></div></div></div></div><div><div><aside><div><div><a><div>text</div></a><div><a><img></a><div><div><div>text</div><ul><li>text</li><li>text</li><li>text</li></ul></div><div><div><a><div><span>text</span><span>text</span></div></a></div><a>text</a></div></div></div></div></div></aside></div></div><div><div><ul><li><a><i></i></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li><a><span>text</span></a></li><li>text<i></i><i></i><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></li></ul><div><div><a>text</a></div></div></div></div></nav><div><div></div></div><div></div><div><div><div><nav><span>text</span><ul><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li><li><a>text</a></li></ul></nav></div></div><div></div><div><aside><p>text<a>text</a>text</p></aside></div><div></div><article><header><nav><ol><li><a>text</a></li><li><a>text</a></li></ol></nav><h1>text</h1><div><div><div><div><div>text<span><a>text</a></span></div><span>text<span><span><time>text</time></span></span></span></div></div></div><p>text</p><nav><ul><li><a><svg><circle></circle><path></path></svg></a></li><li><a><svg><circle></circle><path></path></svg></a></li><li><a><svg><path></path></svg></a></li><li><a><i></i></a></li><li><a><svg><circle></circle><path></path></svg></a></li><li><a><svg><path></path><path></path></svg></a></li><li><a><i></i></a></li></ul><a><i></i><span>text</span></a></nav></div></header><section><div><div><div><div><picture><source></source><source></source><img></picture></div></div></div><figcaption><span>text</span></figcaption></div><div></div><div><p><strong>text</strong>text<a>text</a>text</p><div></div><figure><div><div><p><picture><source></source><source></source><img></picture></p></div></div><figcaption><span>text</span></figcaption></figure><p> ...

# %%
x= generate_object_description(html_templates)
x
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 x= generate_object_description(html_templates)
#       2 x
#
# Cell In[19], line 10, in generate_object_description(text, print_lists)
#       5 # openai.api_key = "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"
#       6 openai.api_key = "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"
# ---> 10 response = openai.ChatCompletion.create(
#      11         # model="anthropic/claude-2", # Optional (user controls the default)
#      12         # model="meta-llama/codellama-34b-instruct", # Optional (user controls the default)
#      13         model="openai/gpt-4-32k", # Optional (user controls the default)
#      14         # model="meta-llama/llama-2-70b-chat", # Optional (user controls the default)
#      15         messages=[
#      16                     {"role": "user", "content": f"create a html template using structure from all of the following html templates and deduping the redundant ones:  \n{text}?"},
#      17                 ],
#      18             # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
#      19             #         "X-Title": $YOUR_APP_NAME },
#      20             headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
#      21                     "X-Title": "Deepankar" },
#      22         )
#      23 reply = response.choices[0].message.content
#      24 # l= reply.content.split('\n')
#      25 # svo_triplets= []
#      26 # for triplet in l:
#    (...)
#      35 #     triplet[-1]= triplet[-1].replace(',', '')
#      36 #     svo_triplets.append(tuple(triplet))
#
# File ~/intent_generation/venv/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/intent_generation/venv/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/intent_generation/venv/lib/python3.10/site-packages/openai/api_requestor.py:298, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#    (...)
#     296         request_timeout=request_timeout,
#     297     )
# --> 298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~/intent_generation/venv/lib/python3.10/site-packages/openai/api_requestor.py:700, in APIRequestor._interpret_response(self, result, stream)
#     692     return (
#     693         self._interpret_response_line(
#     694             line, result.status_code, result.headers, stream=True
#     695         )
#     696         for line in parse_stream(result.iter_lines())
#     697     ), True
#     698 else:
#     699     return (
# --> 700         self._interpret_response_line(
#     701             result.content.decode("utf-8"),
#     702             result.status_code,
#     703             result.headers,
#     704             stream=False,
#     705         ),
#     706         False,
#     707     )
#
# File ~/intent_generation/venv/lib/python3.10/site-packages/openai/api_requestor.py:765, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     763 stream_error = stream and "error" in resp.data
#     764 if stream_error or not 200 <= rcode < 300:
# --> 765     raise self.handle_error_response(
#     766         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     767     )
#     768 return resp
#
# APIError: Prompt tokens limit exceeded: 29898 > 20746. To increase: visit https://openrouter.ai/account and add more credits {"error":{"message":"Prompt tokens limit exceeded: 29898 > 20746. To increase: visit https://openrouter.ai/account and add more credits","code":402}} 402 {'error': {'message': 'Prompt tokens limit exceeded: 29898 > 20746. To increase: visit https://openrouter.ai/account and add more credits', 'code': 402}} {'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': 'Authorization, X-Api-Key, X-CSRF-Token, X-Requested-With, Accept, Accept-Version, Content-Length, Content-MD5, Content-Type, Date, X-Api-Version, HTTP-Referer, X-Windowai-Title, X-Openrouter-Title, X-Title, X-Stainless-Lang, X-Stainless-Package-Version, X-Stainless-OS, X-Stainless-Arch, X-Stainless-Runtime, X-Stainless-Runtime-Version', 'Access-Control-Allow-Methods': 'GET,OPTIONS,PATCH,DELETE,POST,PUT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'public, max-age=0, must-revalidate', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Date': 'Thu, 07 Sep 2023 05:33:48 GMT', 'Server': 'Vercel', 'Strict-Transport-Security': 'max-age=63072000', 'X-Matched-Path': '/api/v1/chat/completions', 'X-Vercel-Cache': 'MISS', 'X-Vercel-Id': 'iad1::tkwmf-1694064825308-3d5c299c2b52', 'Transfer-Encoding': 'chunked'}

# %%
with open('dummy_files/output.html', 'w') as f:
    f.write(x.replace("\n", ''))

# %%
# x
# Out:
# '\n```\n\n### 2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2.2'

# %%
import requests
from bs4 import BeautifulSoup

# %%
url= 'https://openrouter.ai/docs#models'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.tagStack
# Out:
# [<!DOCTYPE html>
#  <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><title>OpenRouter</title><meta content="follow, index" name="robots"/><link href="/favicon.ico" rel="shortcut icon"/><meta content="Authenticate and use your AI models in one place" name="description"/><meta content="https://openrouter.ai/docs" property="og:url"/><meta content="website" property="og:type"/><meta content="OpenRouter" property="og:site_name"/><meta content="Authenticate and use your AI models in one place" property="og:description"/><meta content="OpenRouter" property="og:title"/><meta content="https://openrouter.ai/og.png" property="og:image"/><meta content="summary_large_image" name="twitter:card"/><meta content="@openrouterai" name="twitter:site"/><meta content="OpenRouter" name="twitter:title"/><meta content="Authenticate and use your AI models in one place" name="twitter:description"/><meta content="https://openrouter.ai/og.png" name="twitter:image"/><meta content="17" name="next-head-count"/><link as="font" crossorigin="anonymous" data-next-font="size-adjust" href="/_next/static/media/2aaf0723e720e8b9-s.p.woff2" rel="preload" type="font/woff2"/><link as="style" href="/_next/static/css/de4e0e9c96f37912.css" rel="preload"/><link data-n-g="" href="/_next/static/css/de4e0e9c96f37912.css" rel="stylesheet"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-78c92fac7aa8fdd8.js"></script><script defer="" src="/_next/static/chunks/webpack-af22cb1d49760b49.js"></script><script defer="" src="/_next/static/chunks/framework-22a8c6fdafff7a51.js"></script><script defer="" src="/_next/static/chunks/main-56b96b6ecaea6a63.js"></script><script defer="" src="/_next/static/chunks/pages/_app-402561aeab46fd36.js"></script><script defer="" src="/_next/static/chunks/32331dc1-05607c449f79a2f7.js"></script><script defer="" src="/_next/static/chunks/232-33a4f2cce2a252a0.js"></script><script defer="" src="/_next/static/chunks/150-7d665b265b20cec8.js"></script><script defer="" src="/_next/static/chunks/125-5cc3d621929d2a89.js"></script><script defer="" src="/_next/static/chunks/509-1e67ddd7540f20ba.js"></script><script defer="" src="/_next/static/chunks/pages/docs-6ae0584dba21872b.js"></script><script defer="" src="/_next/static/Wo7Fz6OzCnlFjj29Yh_tj/_buildManifest.js"></script><script defer="" src="/_next/static/Wo7Fz6OzCnlFjj29Yh_tj/_ssgManifest.js"></script></head><body class="loading"><div id="__next"><div class="__variable_20951f font-sans"><script>!function(){try{var d=document.documentElement,c=d.classList;c.remove('light','dark');var e=localStorage.getItem('theme');if('system'===e||(!e&&true)){var t='(prefers-color-scheme: dark)',m=window.matchMedia(t);if(m.media!==t||m.matches){d.style.colorScheme = 'dark';c.add('dark')}else{d.style.colorScheme = 'light';c.add('light')}}else if(e){c.add(e|| '')}if(e==='light'||e==='dark')d.style.colorScheme=e}catch(e){}}()</script><style>
#      #nprogress {
#        pointer-events: none;
#      }
#      #nprogress .bar {
#        background: #6366f1;
#        position: fixed;
#        z-index: 9999;
#        top: 0;
#        left: 0;
#        width: 100%;
#        height: 3px;
#      }
#      #nprogress .peg {
#        display: block;
#        position: absolute;
#        right: 0px;
#        width: 100px;
#        height: 100%;
#        box-shadow: 0 0 10px #6366f1, 0 0 5px #6366f1;
#        opacity: 1;
#        -webkit-transform: rotate(3deg) translate(0px, -4px);
#        -ms-transform: rotate(3deg) translate(0px, -4px);
#        transform: rotate(3deg) translate(0px, -4px);
#      }
#      #nprogress .spinner {
#        display: block;
#        position: fixed;
#        z-index: 1031;
#        top: 15px;
#        right: 15px;
#      }
#      #nprogress .spinner-icon {
#        width: 18px;
#        height: 18px;
#        box-sizing: border-box;
#        border: solid 2px transparent;
#        border-top-color: #6366f1;
#        border-left-color: #6366f1;
#        border-radius: 50%;
#        -webkit-animation: nprogresss-spinner 400ms linear infinite;
#        animation: nprogress-spinner 400ms linear infinite;
#      }
#      .nprogress-custom-parent {
#        overflow: hidden;
#        position: relative;
#      }
#      .nprogress-custom-parent #nprogress .spinner,
#      .nprogress-custom-parent #nprogress .bar {
#        position: absolute;
#      }
#      @-webkit-keyframes nprogress-spinner {
#        0% {
#          -webkit-transform: rotate(0deg);
#        }
#        100% {
#          -webkit-transform: rotate(360deg);
#        }
#      }
#      @keyframes nprogress-spinner {
#        0% {
#          transform: rotate(0deg);
#        }
#        100% {
#          transform: rotate(360deg);
#        }
#      }
#    </style><div class="flex min-h-[calc(100vh-80px)] md:min-h-screen flex-col mx-auto max-w-6xl bg-background text-foreground"><nav class="Navbar_root__QgVqp bg-background"><a class="sr-only focus:not-sr-only" href="#skip">Skip to content</a><div class="px-6"><div class="flex justify-between align-center flex-row py-4 md:py-6 relative text-sm md:text-base"><div class="flex flex-1 items-center"><a class="Navbar_logoWrapper__ZUfBO" href="/"><svg aria-label="Logo" class="Navbar_logo__INhgK" height="100%" viewbox="0 0 512 512" width="100%" xmlns="http://www.w3.org/2000/svg"><g clip-path="url(#clip0_205_3)"><path d="M3 248.945C18 248.945 76 236 106 219C136 202 136 202 198 158C276.497 102.293 332 120.945 423 120.945" stroke-width="90"></path><path d="M511 121.5L357.25 210.268L357.25 32.7324L511 121.5Z"></path><path d="M0 249C15 249 73 261.945 103 278.945C133 295.945 133 295.945 195 339.945C273.497 395.652 329 377 420 377" stroke-width="90"></path><path d="M508 376.445L354.25 287.678L354.25 465.213L508 376.445Z"></path></g><defs><clippath id="clip0_205_3"><rect fill="white" height="512" width="512"></rect></clippath></defs></svg>OpenRouter</a><nav class="space-x-2 md:space-x-6 ml-6 hidden md:flex"><a class="Navbar_link__teYe1 text-slate-10 hover:text-slate-11" href="/playground">Playground</a></nav></div><div class="flex flex-1 justify-end space-x-2 md:space-x-6"><nav aria-label="Main" class="relative z-10 flex max-w-max flex-1 items-center justify-center md:hidden" data-orientation="horizontal" dir="ltr"><div style="position:relative"><ul class="group flex flex-1 list-none items-center justify-center space-x-1" data-orientation="horizontal" dir="ltr"><li><button aria-controls="radix-:R6ism:-content-radix-:R36ism:" aria-expanded="false" class="group inline-flex h-9 w-max items-center justify-center rounded-md bg-background px-4 py-2 text-sm font-medium transition-colors hover:bg-accent hover:text-accent-foreground focus:bg-accent focus:text-accent-foreground focus:outline-none disabled:pointer-events-none disabled:opacity-50 data-[active]:bg-accent/50 data-[state=open]:bg-accent/50 group" data-radix-collection-item="" data-state="closed" id="radix-:R6ism:-trigger-radix-:R36ism:">Menu<!-- --> <svg aria-hidden="true" class="relative top-[1px] ml-1 h-3 w-3 transition duration-300 group-data-[state=open]:rotate-180" fill="none" stroke="currentColor" stroke-width="1.5" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19.5 8.25l-7.5 7.5-7.5-7.5" stroke-linecap="round" stroke-linejoin="round"></path></svg></button></li></ul></div><div class="absolute left-0 top-full flex justify-center"></div></nav><div class="md:flex hidden md:space-x-6"><a class="Navbar_link__teYe1 text-slate-12" href="/docs">Docs</a></div><div class="relative"><button aria-expanded="true" aria-haspopup="true" class="inline-flex items-center justify-center w-full rounded-md py-2 px-2" id="options-menu" type="button"><svg aria-hidden="true" class="opacity-50 h-[1.2rem] w-[1.2rem] dark:hidden" fill="currentColor" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2.25a.75.75 0 01.75.75v2.25a.75.75 0 01-1.5 0V3a.75.75 0 01.75-.75zM7.5 12a4.5 4.5 0 119 0 4.5 4.5 0 01-9 0zM18.894 6.166a.75.75 0 00-1.06-1.06l-1.591 1.59a.75.75 0 101.06 1.061l1.591-1.59zM21.75 12a.75.75 0 01-.75.75h-2.25a.75.75 0 010-1.5H21a.75.75 0 01.75.75zM17.834 18.894a.75.75 0 001.06-1.06l-1.59-1.591a.75.75 0 10-1.061 1.06l1.59 1.591zM12 18a.75.75 0 01.75.75V21a.75.75 0 01-1.5 0v-2.25A.75.75 0 0112 18zM7.758 17.303a.75.75 0 00-1.061-1.06l-1.591 1.59a.75.75 0 001.06 1.061l1.591-1.59zM6 12a.75.75 0 01-.75.75H3a.75.75 0 010-1.5h2.25A.75.75 0 016 12zM6.697 7.757a.75.75 0 001.06-1.06l-1.59-1.591a.75.75 0 00-1.061 1.06l1.59 1.591z"></path></svg><svg aria-hidden="true" class="opacity-50 h-[1.2rem] w-[1.2rem] hidden dark:block" fill="currentColor" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M9.528 1.718a.75.75 0 01.162.819A8.97 8.97 0 009 6a9  ...

# %%
from main import generate_intent_v2

# %%
from Utils.client import generate_top_urls

# %%
generate_top_urls("spotify free vs premium")
# Out:
# ['https://www.tomsguide.com/face-off/spotify-free-vs-premium',
#  'https://www.soundguys.com/free-spotify-vs-spotify-premium-36632/',
#  'https://www.headphonesty.com/2021/08/spotify-free-vs-premium/',
#  'https://www.quora.com/What-is-the-difference-between-free-Spotify-and-Premium',
#  'https://history-computer.com/spotify-free-vs-premium-comparison-whats-the-difference/',
#  'https://www.cnet.com/tech/services-and-software/good-reasons-to-pay-for-spotify/',
#  'https://support.spotify.com/us/article/premium-plans/',
#  'https://www.geeky-gadgets.com/whats-difference-between-spotify-free-and-premium/',
#  'https://www.spotify.com/us/premium/',
#  'https://www.viwizard.com/spotify-music-tips/spotify-free-vs-premium.html']

# %%
generate_intent_v2("spotify free vs premium")
# Out:
# Spotify Free vs. Premium: Should you pay to play? www.tomsguide.com https://www.tomsguide.com/face-off/spotify-free-vs-premium Arguably the biggest difference between Spotify's Free and Premium tiers is the latter's complete lack of ads. That goes for both the visual ads ... Spotify Free vs Premium: Is it worth it? www.soundguys.com https://www.soundguys.com/free-spotify-vs-spotify-premium-36632/ First, there is the Spotify Premium Individual subscription, which is $9.99/month. This allows access to all the Premium features such as no ad interruptions, ... Spotify Free vs. Premium Comparison: What's the Difference? history-computer.com https://history-computer.com/spotify-free-vs-premium-comparison-whats-the-difference/ Spotify Free is completely free, while Premium costs $9.99 per month. There are also three other plans: $15.99/month for a family plan (up to ... What is the difference between free Spotify and Premium? www.quora.com https://www.quora.com/What-is-the-difference-between-free-Spotify-and-Premium The main difference between free Spotify and Premium is that the free version includes ads and has limited features, while Premium offers ad-free listening, ... Spotify Premium vs. Free: 6 Good Reasons to Pay www.cnet.com https://www.cnet.com/tech/services-and-software/good-reasons-to-pay-for-spotify/ Spotify Premium adds Very High quality streaming at 320 Kbps, which can make for better, more detailed audio output if you use high-end ... Spotify Free vs. Premium: Should You Upgrade? www.headphonesty.com https://www.headphonesty.com/2021/08/spotify-free-vs-premium/ Spotify Free is the platform's free plan. It gives you access to the entire library of content but comes with ads and limitations, which we'll ... Premium plans - Spotify support.spotify.com https://support.spotify.com/us/article/premium-plans/ 6 people living together each get their own Premium account for 1 discount price. Premium Family comes with: Spotify Kids - an app packed with singalongs, ... What's the difference between Spotify Free and Premium www.geeky-gadgets.com https://www.geeky-gadgets.com/whats-difference-between-spotify-free-and-premium/ The Premium version comes with unlimited skips, unlike the free version and it also comes with higher-quality audio. On the free version, music ... Spotify Premium - Get 3 months free www.spotify.com https://www.spotify.com/us/premium/ Free for 1 month, then $16.99 per month after. Offer only available if you haven't tried Premium before. For up to 6 family members residing at the same address ... Spotify Free VS Premium: Should I Pay or Stay Free in 2023? www.viwizard.com https://www.viwizard.com/spotify-music-tips/spotify-free-vs-premium.html Spotify Premium isn't just about ad-free music and better quality. It goes further, offering exclusive features not available to Spotify Free ...
# spotify free vs premium:
#  tensor([[0.8669],
#         [0.8687],
#         [0.8446],
#         [0.8523],
#         [0.8388]])
# ('navigational',
#  0.8687077164649963,
#  tensor([[0.8669],
#          [0.8687],
#          [0.8446],
#          [0.8523],
#          [0.8388]]))

# %%
from main import generate_base_embeddings_v2

# %%
s= "cats fight with dogs"
sl= s.split(' ')
sl
# Out:
# ['cats', 'fight', 'with', 'dogs']

# %%
import numpy as np

# %%
e2= np.mean(generate_base_embeddings_v2(sl), axis=0)

# %%
s= "car runs faster than bike"
sl= s.split(' ')
sl
e1= np.mean(generate_base_embeddings_v2(sl), axis=0)

# %%
e1==e2
# Out:
# array([False, False, False, ..., False, False, False])

# %%
from main import generate_cosine_similarity

# %%
generate_cosine_similarity(e1, e2)
# Out:
# tensor([[0.9320]])
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
