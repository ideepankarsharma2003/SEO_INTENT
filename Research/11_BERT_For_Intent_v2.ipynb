# %%
import os; os.chdir('..')

# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("data/keyword_intent.csv")
data.head()
# Out:
#                              keyword         intent
# 0               citalopram vs prozac     Commercial
# 1  who is the oldest football player  Informational
# 2                 t mobile town east   Navigational
# 3                          starbucks   Navigational
# 4                        tech crunch   Navigational

# %%
data.intent= data.intent.map(str.lower)

# %%
data.intent.unique()
# Out:
# array(['commercial', 'informational', 'navigational', 'local',
#        'transactional'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set()
plt.figure(figsize = (12, 8))
chart = sns.countplot(x = 'intent', data = data, palette='Set1')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 30, horizontalalignment='right', fontweight='light', fontsize='medium')
chart.set_title('Intent Distribution', fontsize = 18)
chart.set_xlabel('Intents', fontsize = 14)
chart.set_ylabel('Counts', fontsize = 14)
plt.show()
# Out:
# /tmp/ipykernel_511430/2131295463.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   chart = sns.countplot(x = 'intent', data = data, palette='Set1')
# /tmp/ipykernel_511430/2131295463.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(chart.get_xticklabels(), rotation = 30, horizontalalignment='right', fontweight='light', fontsize='medium')

# %%
# ! wget "https://storage.googleapis.com/bert_models/2020_02_20/uncased_L-12_H-768_A-12.zip"

# %%
import shutil 
shutil.unpack_archive("uncased_L-12_H-768_A-12.zip", "models/uncased_L-12_H-768_A-12")

# %%
import os
modelInputFolder = 'models'
bert_model_name="uncased_L-12_H-768_A-12"
bert_ckpt_dir = os.path.join(modelInputFolder, bert_model_name)
bert_ckpt_file = os.path.join(bert_ckpt_dir, "bert_model.ckpt")
bert_config_file = os.path.join(bert_ckpt_dir, "bert_config.json")
print(bert_ckpt_dir)
print(bert_ckpt_file)
print(bert_config_file)
# Out:
# models/uncased_L-12_H-768_A-12
# models/uncased_L-12_H-768_A-12/bert_model.ckpt
# models/uncased_L-12_H-768_A-12/bert_config.json

# %%
vocab_file = os.path.join(bert_ckpt_dir, "vocab.txt")
print(vocab_file)
# Out:
# models/uncased_L-12_H-768_A-12/vocab.txt

# %%
# !pip install bert-tensorflow
# !pip install bert-for-tf2 # this one
# !pip install bert-tokenizer
# Out:
# /bin/bash: /home/ubuntu/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Collecting bert-tensorflow
#   Using cached bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
# Requirement already satisfied: six in ./venv/lib/python3.10/site-packages (from bert-tensorflow) (1.16.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
# !pip uninstall -y bert-tensorflow
# !pip uninstall -y bert-for-tf2
# !pip uninstall -y bert-tokenizer
# Out:
# /bin/bash: /home/ubuntu/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# WARNING: Skipping bert-tensorflow as it is not installed.
# /bin/bash: /home/ubuntu/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Found existing installation: bert-for-tf2 0.14.9
# Uninstalling bert-for-tf2-0.14.9:
#   Successfully uninstalled bert-for-tf2-0.14.9
# /bin/bash: /home/ubuntu/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# WARNING: Skipping bert-tokenizer as it is not installed.

# %%
from bert.tokenization import FullTokenizer

# %%
#Import FullTokenizer from bert_tokenization
# from bert.tokenization.bert_tokenization import FullTokenizer

# %%
tokenizer = FullTokenizer(vocab_file)
print(tokenizer)
# Out:
# <bert.tokenization.FullTokenizer object at 0x7f3b22ee0220>

# %%
from bert.tokenization import FullTokenizer

# %%
tokenizer.tokenize()

# %%
tokens = tokenizer.tokenize("Hello, How are you?")
# token_ids = tokenizer.convert_tokens_to_ids(tokens)
# print(tokens)
# print(token_ids)
# Out:
# ---------------------------------------------------------------------------
# UnparsedFlagAccessError                   Traceback (most recent call last)
# /home/ubuntu/intent_generation/Research/11_BERT_For_Intent_v2.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22456d62656464696e6773227d/home/ubuntu/intent_generation/Research/11_BERT_For_Intent_v2.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> tokens = tokenizer.tokenize("Hello, How are you?")
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22456d62656464696e6773227d/home/ubuntu/intent_generation/Research/11_BERT_For_Intent_v2.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # token_ids = tokenizer.convert_tokens_to_ids(tokens)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22456d62656464696e6773227d/home/ubuntu/intent_generation/Research/11_BERT_For_Intent_v2.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # print(tokens)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22456d62656464696e6773227d/home/ubuntu/intent_generation/Research/11_BERT_For_Intent_v2.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # print(token_ids)
#
# File ~/intent_generation/venv/lib/python3.10/site-packages/bert/tokenization.py:192, in FullTokenizer.tokenize(self, text)
#     190 def tokenize(self, text):
#     191   split_tokens = []
# --> 192   for token in self.basic_tokenizer.tokenize(text):
#     193     if preserve_token(token, self.vocab):
#     194       split_tokens.append(token)
#
# File ~/intent_generation/venv/lib/python3.10/site-packages/bert/tokenization.py:237, in BasicTokenizer.tokenize(self, text)
#     235 split_tokens = []
#     236 for token in orig_tokens:
# --> 237   if preserve_token(token, self.vocab):
#     238     split_tokens.append(token)
#     239     continue
#
# File ~/intent_generation/venv/lib/python3.10/site-packages/bert/tokenization.py:41, in preserve_token(token, vocab)
#      39 def preserve_token(token, vocab):
#      40   """Returns True if the token should forgo tokenization and be preserved."""
# ---> 41   if not FLAGS.preserve_unused_tokens:
#      42     return False
#      43   if token not in vocab:
#
# File ~/intent_generation/venv/lib/python3.10/site-packages/absl/flags/_flagvalues.py:498, in FlagValues.__getattr__(self, name)
#     496   return fl[name].value
#     497 else:
# --> 498   raise _exceptions.UnparsedFlagAccessError(
#     499       'Trying to access flag --%s before flags were parsed.' % name)
#
# UnparsedFlagAccessError: Trying to access flag --preserve_unused_tokens before flags were parsed.
